# %% [markdown]
# # Big Data Management and Processing

# %% [markdown]
# Exercises submitted via Python Notebook to keep queries and output close together and easily readable :)

# %% [markdown]
# ## Setup and imports

# %%
from bson.code import Code
import pandas as pd
from pprint import pprint
from pymongo import MongoClient

client = MongoClient('localhost', 27017)
cities = client.bdmp['cities']
regions = client.bdmp['regions']
countries = client.bdmp['countries']

# %% [markdown]
# ## Exercise 1: Queries

# %% [markdown]
# Select all Austrian cities (`countryID = 15`)!

# %%
pd.DataFrame(cities.find({'CountryID': 15}))
# Out:
#                          _id  CityId  CountryID  RegionID  \
# 0   50bebc7714b6500c5cb78ffe    3352         15      1083
# 1   50bebc7714b6500c5cb78fff    3353         15      1080
# 2   50bebc7814b6500c5cb79000    3354         15      1081
# 3   50bebc7814b6500c5cb79001    3355         15      1077
# 4   50bebc7814b6500c5cb79002    3356         15      1078
# 5   50bebc7914b6500c5cb79003    3357         15      1079
# 6   50bebc7914b6500c5cb79004    3358         15      1081
# 7   50bebc7914b6500c5cb79005    3361         15      1075
# 8   50bebc7a14b6500c5cb79006    3362         15      1078
# 9   50bebde014b6500c5cb79340    6033         15      1081
# 10  50bebde014b6500c5cb79341    6034         15      1083
# 11  50bebe1d14b6500c5cb793db   12329         15      1082
# 12  50bebe1f14b6500c5cb793e1   12399         15      1082
# 13  50bebe2314b6500c5cb793e9   12466         15      1077
# 14  50bebe2414b6500c5cb793ea   12467         15      1076
# 15  50bebe3314b6500c5cb79414   12867         15      1081
# 16  50bebe3914b6500c5cb79422   12956         15      1081
# 17  50bebe4b14b6500c5cb79451   13317         15      1077
# 18  50bebe4d14b6500c5cb79457   13364         15      1077
# 19  50bebe4f14b6500c5cb7945d   13439         15      1075
# 20  50bebe5514b6500c5cb7946c   13557         15      1081
# 21  50bebe5714b6500c5cb79471   13625         15      1077
# 22  50bebe6014b6500c5cb79482   13801         15      1077
# 23  50bebe7a14b6500c5cb794c3   14361         15      1080
# 24  50bebe8d14b6500c5cb794ee   14704         15      1076
# 25  50bebe9014b6500c5cb794f3   14725         15      1082
# 26  50bebe9a14b6500c5cb79508   14860         15      1078
# 27  50bebe9f14b6500c5cb79517   15003         15      1075
# 28  50bebeaf14b6500c5cb79541   15407         15      1080
# 29  50bebeb314b6500c5cb7954c   15467         15      1076
# 30  50bebeb814b6500c5cb79559   15557         15      1077
# 31  50bebebc14b6500c5cb79563   15616         15      1077
# 32  50bebed414b6500c5cb79581   15858         15      1077
# 33  50bebedc14b6500c5cb79597   15948         15      1077
# 34  50bebefa14b6500c5cb795e2   16515         15      1078
# 35  50bebefe14b6500c5cb795eb   16597         15      1075
# 36  50bebf0414b6500c5cb795fb   16779         15      1076
# 37  50bebf0414b6500c5cb795fc   16781         15      1076
# 38  50bebf0514b6500c5cb795ff   16815         15      1077
# 39  50bebf0614b6500c5cb79600   16818         15      1081
# 40  50bebf0f14b6500c5cb79619   17005         15      1078
# 41  50bebf1314b6500c5cb7961e   17045         15      1080
# 42  50bebf1414b6500c5cb79623   17142         15      1079
# 43  50bebf1614b6500c5cb79627   17233         15      1077
# 44  50bebf1614b6500c5cb79628   17234         15      1083
# 45  50bebf1914b6500c5cb79630   17285         15      1075
# 46  50bebf1d14b6500c5cb79638   17391         15      1077
# 47  50bebf3214b6500c5cb7966c   17897         15      1077
# 48  50bebf5114b6500c5cb796a2   18389         15      1079
# 49  50bebf6c14b6500c5cb796e6   41729         15      1079
# 50  50bebf7e14b6500c5cb7970f   41890         15      1077
# 51  50bebf8614b6500c5cb79726   41999         15      1082
# 52  50bebf8f14b6500c5cb7973b   42058         15      1078
# 53  50bebfb814b6500c5cb7979d   42953         15      1077
#
#                       City   Latitude  Longitude TimeZone  DmaId  Code
# 0                  Abtenau  47.549999  13.350000   +01:00      0  ABTE
# 1                     Graz  47.067001  15.450000   +01:00      0  GRAZ
# 2                Kitzbuhel  47.450001  12.383000   +01:00      0  KITZ
# 3               Lilienfeld  48.016998  15.633000   +01:00      0  LILI
# 4                     Linz  48.299999  14.300000   +01:00      0  LINZ
# 5                 Salzburg  47.799999  13.033000   +01:00      0  SALZ
# 6                   Solden  46.966999  11.000000   +01:00      0  SOLD
# 7              Stegersbach  47.167000  16.167000   +01:00      0  STEG
# 8                    Steyr  48.049999  14.417000   +01:00      0  STEY
# 9                Innsbruck  47.266998  11.400000   +01:00      0  INNS
# 10                  Vienna  48.200001  16.367001   +01:00      0  VIEN
# 11                Hohenems  47.367001   9.683000   +01:00      0  HOHE
# 12                 Bregenz  47.500000   9.767000   +01:00      0  BREG
# 13                   Baden  48.016998  16.233000   +01:00      0  BADE
# 14                       D  46.783001  13.660000   +01:00      0     D
# 15                    Zirl  47.283001  11.233000   +01:00      0  ZIRL
# 16                       W  47.483002  12.067000   +01:00      0     W
# 17              Korneuburg  48.349998  16.333000   +01:00      0  KORN
# 18              Wieselburg  48.132999  15.133000   +01:00      0  WIES
# 19               Pinkafeld  47.367001  16.117001   +01:00      0  PINK
# 20                Jochberg  47.382999  12.400000   +01:00      0  JOCH
# 21         Wiener Neustadt  47.799999  16.250000   +01:00      0  WNEU
# 22                 Zwettl   48.617001  15.167000   +01:00      0  ZWET
# 23                  Leoben  47.382999  15.100000   +01:00      0  LEOB
# 24             Feldkirchen  46.716999  14.100000   +01:00      0  FELD
# 25                Dornbirn  47.417000   9.733000   +01:00      0  DORN
# 26                Bad Hall  48.033001  14.200000   +01:00      0  BHAL
# 27                    Neud  47.783001  16.283001   +01:00      0  NEUD
# 28                Kindberg  47.500000  15.450000   +01:00      0  KIND
# 29              Klagenfurt  46.625000  14.305000   +01:00      0  KLAG
# 30                       M  48.083000  16.283001   +01:00      0     M
# 31             Neulengbach  48.200001  15.900000   +01:00      0  NEUL
# 32                       G  48.349998  16.733000   +01:00      0     G
# 33                    Retz  48.750000  15.950000   +01:00      0  RETZ
# 34               Hagenberg  48.367001  14.517000   +01:00      0  HAGE
# 35              Eisenstadt  47.849998  16.517000   +01:00      0  EISE
# 36                 Villach  46.610001  13.856000   +01:00      0  VILL
# 37              Bodensdorf  46.691002  13.971000   +01:00      0  BODE
# 38                Rosental  48.033001  16.183001   +01:00      0  ROSE
# 39                  Reutte  47.483002  10.717000   +01:00      0  REUT
# 40                    Wels  48.167000  14.033000   +01:00      0  WELS
# 38  50bebf6c14b6500c5cb796e6   41729         15      1079
# 39  50bebf3214b6500c5cb7966c   17897         15      1077
# 40  50bebc7914b6500c5cb79004    3358         15      1081
# 41  50bebc7914b6500c5cb79005    3361         15      1075
# 42  50bebc7a14b6500c5cb79006    3362         15      1078
# 43  50bebf1414b6500c5cb79623   17142         15      1079
# 44  50bebde014b6500c5cb79341    6034         15      1083
# 45  50bebf0414b6500c5cb795fb   16779         15      1076
# 46  50bebe3914b6500c5cb79422   12956         15      1081
# 47  50bebf0f14b6500c5cb79619   17005         15      1078
# 48  50bebf1614b6500c5cb79628   17234         15      1083
# 49  50bebe5714b6500c5cb79471   13625         15      1077
# 50  50bebe4d14b6500c5cb79457   13364         15      1077
# 51  50bebf5114b6500c5cb796a2   18389         15      1079
# 52  50bebe3314b6500c5cb79414   12867         15      1081
# 53  50bebe6014b6500c5cb79482   13801         15      1077
#
#                       City   Latitude  Longitude TimeZone  DmaId  Code
# 0                  Abtenau  47.549999  13.350000   +01:00      0  ABTE
# 1                 Bad Hall  48.033001  14.200000   +01:00      0  BHAL
# 2                    Bad V  47.966999  16.200001   +01:00      0    BV
# 3                    Baden  48.016998  16.233000   +01:00      0  BADE
# 4               Bodensdorf  46.691002  13.971000   +01:00      0  BODE
# 5                  Bregenz  47.500000   9.767000   +01:00      0  BREG
# 6                        D  46.783001  13.660000   +01:00      0     D
# 7                 Dornbirn  47.417000   9.733000   +01:00      0  DORN
# 8             Ebreichsdorf  47.950001  16.400000   +01:00      0  EBRE
# 9               Eisenstadt  47.849998  16.517000   +01:00      0  EISE
# 10             Feldkirchen  46.716999  14.100000   +01:00      0  FELD
# 11                       G  48.349998  16.733000   +01:00      0     G
# 12                       G  47.067001  16.333000   +01:00      0     G
# 13                       G  47.333000   9.633000   +01:00      0     G
# 14              Grafenbach  47.682999  16.000000   +01:00      0  GRAF
# 15                    Graz  47.067001  15.450000   +01:00      0  GRAZ
# 16               Hagenberg  48.367001  14.517000   +01:00      0  HAGE
# 17                Hohenems  47.367001   9.683000   +01:00      0  HOHE
# 18               Innsbruck  47.266998  11.400000   +01:00      0  INNS
# 19                Jochberg  47.382999  12.400000   +01:00      0  JOCH
# 20                Kindberg  47.500000  15.450000   +01:00      0  KIND
# 21               Kitzbuhel  47.450001  12.383000   +01:00      0  KITZ
# 22              Klagenfurt  46.625000  14.305000   +01:00      0  KLAG
# 23         Klosterneuburg   48.310101  16.322599   +01:00      0  KLOS
# 24              Korneuburg  48.349998  16.333000   +01:00      0  KORN
# 25                  Kremsm  48.049999  14.133000   +01:00      0  KREM
# 26                  Leoben  47.382999  15.100000   +01:00      0  LEOB
# 27              Lilienfeld  48.016998  15.633000   +01:00      0  LILI
# 28                    Linz  48.299999  14.300000   +01:00      0  LINZ
# 29                       M  48.083000  16.283001   +01:00      0     M
# 30                       M  47.599998  15.683000   +01:00      0     M
# 31                    Neud  47.783001  16.283001   +01:00      0  NEUD
# 32             Neulengbach  48.200001  15.900000   +01:00      0  NEUL
# 33               Pinkafeld  47.367001  16.117001   +01:00      0  PINK
# 34                    Retz  48.750000  15.950000   +01:00      0  RETZ
# 28                  Kremsm  48.049999  14.133000   +01:00      0  KREM
# 29              Korneuburg  48.349998  16.333000   +01:00      0  KORN
# 30         Klosterneuburg   48.310101  16.322599   +01:00      0  KLOS
# 31              Klagenfurt  46.625000  14.305000   +01:00      0  KLAG
# 32               Kitzbuhel  47.450001  12.383000   +01:00      0  KITZ
# 33                Kindberg  47.500000  15.450000   +01:00      0  KIND
# 34                Jochberg  47.382999  12.400000   +01:00      0  JOCH
# 35               Innsbruck  47.266998  11.400000   +01:00      0  INNS
# 36                Hohenems  47.367001   9.683000   +01:00      0  HOHE
# 37               Hagenberg  48.367001  14.517000   +01:00      0  HAGE
# 38                    Graz  47.067001  15.450000   +01:00      0  GRAZ
# 39              Grafenbach  47.682999  16.000000   +01:00      0  GRAF
# 40                       G  48.349998  16.733000   +01:00      0     G
# 41                       G  47.067001  16.333000   +01:00      0     G
# 42                       G  47.333000   9.633000   +01:00      0     G
# 43             Feldkirchen  46.716999  14.100000   +01:00      0  FELD
# 44              Eisenstadt  47.849998  16.517000   +01:00      0  EISE
# 45            Ebreichsdorf  47.950001  16.400000   +01:00      0  EBRE
# 46                Dornbirn  47.417000   9.733000   +01:00      0  DORN
# 47                       D  46.783001  13.660000   +01:00      0     D
# 48                 Bregenz  47.500000   9.767000   +01:00      0  BREG
# 49              Bodensdorf  46.691002  13.971000   +01:00      0  BODE
# 50                   Baden  48.016998  16.233000   +01:00      0  BADE
# 51                   Bad V  47.966999  16.200001   +01:00      0    BV
# 52                Bad Hall  48.033001  14.200000   +01:00      0  BHAL
# 53                 Abtenau  47.549999  13.350000   +01:00      0  ABTE

# %% [markdown]
# Select the number of Austrian cities that are included in the dataset!

# %%
cities.count_documents({'CountryID': 15})
# Out:
# 54

# %% [markdown]
# Select solely the city names of all Austrian cities!

# %%
pd.DataFrame(cities.find({'CountryID': 15}, {'City': 1, '_id': 0}))
# Out:
#                       City
# 0                  Abtenau
# 1                     Graz
# 2                Kitzbuhel
# 3               Lilienfeld
# 4                     Linz
# 5                 Salzburg
# 6                   Solden
# 7              Stegersbach
# 8                    Steyr
# 9                Innsbruck
# 10                  Vienna
# 11                Hohenems
# 12                 Bregenz
# 13                   Baden
# 14                       D
# 15                    Zirl
# 16                       W
# 17              Korneuburg
# 18              Wieselburg
# 19               Pinkafeld
# 20                Jochberg
# 21         Wiener Neustadt
# 22                 Zwettl
# 23                  Leoben
# 24             Feldkirchen
# 25                Dornbirn
# 26                Bad Hall
# 27                    Neud
# 28                Kindberg
# 29              Klagenfurt
# 30                       M
# 31             Neulengbach
# 32                       G
# 33                    Retz
# 34               Hagenberg
# 35              Eisenstadt
# 36                 Villach
# 37              Bodensdorf
# 38                Rosental
# 39                  Reutte
# 40                    Wels
# 41                       M
# 42                 Tamsweg
# 43                   Bad V
# 44                    Wien
# 45                       G
# 46              Grafenbach
# 47                 Sankt P
# 48             Zell am See
# 49  Sankt Johann im Pongau
# 50            Ebreichsdorf
# 51                       G
# 52                  Kremsm
# 53         Klosterneuburg

# %% [markdown]
# Select all countries, which exhibit a population between 15 and 20 millions of people!

# %%
pd.DataFrame(countries.find({'Population': {'$gte': 1.5e7, '$lte': 2e7}}))
# Out:
#                         _id  CountryId        Country FIPS104 ISO2 ISO3 ISON  \
# 0  50bebfc814b6500c5cb797c6         42       Cameroon      CM   CM  CMR  120
# 1  50bebfc914b6500c5cb797cb         48          Chile      CI   CL  CHL  152
# 2  50bebfce14b6500c5cb797d6         60  Cote d'Ivoire      IV   CI  CIV  384
# 3  50bebfdc14b6500c5cb797f5         92          Ghana      GH   GH  GHA  288
#
#   Internet       Capital    MapReference NationalitySingular  \
# 0       CM      Yaounde          Africa          Cameroonian
# 1       CL     Santiago   South America              Chilean
# 2       CI  Yamoussoukro         Africa              Ivorian
# 3       GH        Accra          Africa             Ghanaian
#
#   NationalityPlural         Currency CurrencyCode  Population          Title  \
# 0      Cameroonians   CFA Franc BEAC          XAF    15803220       Cameroon
# 1          Chileans    Chilean Peso           CLP    15328467          Chile
# 2          Ivorians  CFA Franc BCEAO          XOF    16393221  Cote d'Ivoire
# 3         Ghanaians             Cedi          GHC    19894014          Ghana
#
#   Comment
# 0
# 1
# 2
# 3

# %% [markdown]
# ## Exercise 2: Updates

# %%
pd.DataFrame(countries.find({'CountryId': 15}))
# Out:
#                         _id  CountryId  Country FIPS104 ISO2 ISO3 ISON  \
# 0  50bebfbd14b6500c5cb797ab         15  Austria      AU   AT  AUT   40
#
#   Internet  Capital MapReference NationalitySingular NationalityPlural  \
# 0       AT  Vienna       Europe             Austrian         Austrians
#
#   Currency CurrencyCode  Population    Title Comment
# 0     Euro          EUR     8150895  Austria

# %% [markdown]
# Increase the population of Austria (`countryID = 15`) by 3 persons

# %%
countries.update_one({'CountryId': 15}, {'$inc': {'Population': 3}})
pd.DataFrame(countries.find({'CountryId': 15}))
# Out:
#                         _id  CountryId  Country FIPS104 ISO2 ISO3 ISON  \
# 0  50bebfbd14b6500c5cb797ab         15  Austria      AU   AT  AUT   40
#
#   Internet  Capital MapReference NationalitySingular NationalityPlural  \
# 0       AT  Vienna       Europe             Austrian         Austrians
#
#   Currency CurrencyCode  Population    Title Comment
# 0     Euro          EUR     8150898  Austria

# %%
countries.update_one({'CountryId': 15}, {'$inc': {'Population': -3}})
pd.DataFrame(countries.find({'CountryId': 15}))
# Out:
#                         _id  CountryId  Country FIPS104 ISO2 ISO3 ISON  \
# 0  50bebfbd14b6500c5cb797ab         15  Austria      AU   AT  AUT   40
#
#   Internet  Capital MapReference NationalitySingular NationalityPlural  \
# 0       AT  Vienna       Europe             Austrian         Austrians
#
#   Currency CurrencyCode  Population    Title Comment
# 0     Euro          EUR     8150895  Austria

# %% [markdown]
# ## Exercise 3: MapReduce: Selection

# %% [markdown]
# Write a MapReduce program, which returns all Austrian cities (full documents!).

# %%
map = Code('function () { emit(this._id, this); }')
reduce = Code('function (key, values) { return values; }')
pd.DataFrame(cities.map_reduce(map, reduce, out='all_cities', query={'CountryID': 15}).find({}))
# Out:
#                          _id  \
# 0   50bebc7714b6500c5cb78ffe
# 1   50bebc7714b6500c5cb78fff
# 2   50bebc7814b6500c5cb79000
# 3   50bebc7814b6500c5cb79001
# 4   50bebc7814b6500c5cb79002
# 5   50bebc7914b6500c5cb79003
# 6   50bebc7914b6500c5cb79004
# 7   50bebc7914b6500c5cb79005
# 8   50bebc7a14b6500c5cb79006
# 9   50bebde014b6500c5cb79340
# 10  50bebde014b6500c5cb79341
# 11  50bebe1d14b6500c5cb793db
# 12  50bebe1f14b6500c5cb793e1
# 13  50bebe2314b6500c5cb793e9
# 14  50bebe2414b6500c5cb793ea
# 15  50bebe3314b6500c5cb79414
# 16  50bebe3914b6500c5cb79422
# 17  50bebe4b14b6500c5cb79451
# 18  50bebe4d14b6500c5cb79457
# 19  50bebe4f14b6500c5cb7945d
# 20  50bebe5514b6500c5cb7946c
# 21  50bebe5714b6500c5cb79471
# 22  50bebe6014b6500c5cb79482
# 23  50bebe7a14b6500c5cb794c3
# 24  50bebe8d14b6500c5cb794ee
# 25  50bebe9014b6500c5cb794f3
# 26  50bebe9a14b6500c5cb79508
# 27  50bebe9f14b6500c5cb79517
# 28  50bebeaf14b6500c5cb79541
# 29  50bebeb314b6500c5cb7954c
# 30  50bebeb814b6500c5cb79559
# 31  50bebebc14b6500c5cb79563
# 32  50bebed414b6500c5cb79581
# 33  50bebedc14b6500c5cb79597
# 34  50bebefa14b6500c5cb795e2
# 35  50bebefe14b6500c5cb795eb
# 36  50bebf0414b6500c5cb795fb
# 37  50bebf0414b6500c5cb795fc
# 38  50bebf0514b6500c5cb795ff
# 39  50bebf0614b6500c5cb79600
# 40  50bebf0f14b6500c5cb79619
# 41  50bebf1314b6500c5cb7961e
# 42  50bebf1414b6500c5cb79623
# 43  50bebf1614b6500c5cb79627
# 44  50bebf1614b6500c5cb79628
# 45  50bebf1914b6500c5cb79630
# 46  50bebf1d14b6500c5cb79638
# 47  50bebf3214b6500c5cb7966c
# 48  50bebf5114b6500c5cb796a2
# 49  50bebf6c14b6500c5cb796e6
# 50  50bebf7e14b6500c5cb7970f
# 51  50bebf8614b6500c5cb79726
# 52  50bebf8f14b6500c5cb7973b
# 53  50bebfb814b6500c5cb7979d
#
#                                                 value
# 0   {'_id': 50bebc7714b6500c5cb78ffe, 'CityId': 33...
# 1   {'_id': 50bebc7714b6500c5cb78fff, 'CityId': 33...
# 2   {'_id': 50bebc7814b6500c5cb79000, 'CityId': 33...
# 3   {'_id': 50bebc7814b6500c5cb79001, 'CityId': 33...
# 4   {'_id': 50bebc7814b6500c5cb79002, 'CityId': 33...
# 5   {'_id': 50bebc7914b6500c5cb79003, 'CityId': 33...
# 6   {'_id': 50bebc7914b6500c5cb79004, 'CityId': 33...
# 7   {'_id': 50bebc7914b6500c5cb79005, 'CityId': 33...
# 8   {'_id': 50bebc7a14b6500c5cb79006, 'CityId': 33...
# 9   {'_id': 50bebde014b6500c5cb79340, 'CityId': 60...
# 10  {'_id': 50bebde014b6500c5cb79341, 'CityId': 60...
# 11  {'_id': 50bebe1d14b6500c5cb793db, 'CityId': 12...
# 12  {'_id': 50bebe1f14b6500c5cb793e1, 'CityId': 12...
# 13  {'_id': 50bebe2314b6500c5cb793e9, 'CityId': 12...
# 14  {'_id': 50bebe2414b6500c5cb793ea, 'CityId': 12...
# 15  {'_id': 50bebe3314b6500c5cb79414, 'CityId': 12...
# 16  {'_id': 50bebe3914b6500c5cb79422, 'CityId': 12...
# 17  {'_id': 50bebe4b14b6500c5cb79451, 'CityId': 13...
# 18  {'_id': 50bebe4d14b6500c5cb79457, 'CityId': 13...
# 19  {'_id': 50bebe4f14b6500c5cb7945d, 'CityId': 13...
# 20  {'_id': 50bebe5514b6500c5cb7946c, 'CityId': 13...
# 21  {'_id': 50bebe5714b6500c5cb79471, 'CityId': 13...
# 22  {'_id': 50bebe6014b6500c5cb79482, 'CityId': 13...
# 23  {'_id': 50bebe7a14b6500c5cb794c3, 'CityId': 14...
# 24  {'_id': 50bebe8d14b6500c5cb794ee, 'CityId': 14...
# 25  {'_id': 50bebe9014b6500c5cb794f3, 'CityId': 14...
# 26  {'_id': 50bebe9a14b6500c5cb79508, 'CityId': 14...
# 27  {'_id': 50bebe9f14b6500c5cb79517, 'CityId': 15...
# 28  {'_id': 50bebeaf14b6500c5cb79541, 'CityId': 15...
# 29  {'_id': 50bebeb314b6500c5cb7954c, 'CityId': 15...
# 30  {'_id': 50bebeb814b6500c5cb79559, 'CityId': 15...
# 31  {'_id': 50bebebc14b6500c5cb79563, 'CityId': 15...
# 32  {'_id': 50bebed414b6500c5cb79581, 'CityId': 15...
# 33  {'_id': 50bebedc14b6500c5cb79597, 'CityId': 15...
# 34  {'_id': 50bebefa14b6500c5cb795e2, 'CityId': 16...
# 35  {'_id': 50bebefe14b6500c5cb795eb, 'CityId': 16...
# 36  {'_id': 50bebf0414b6500c5cb795fb, 'CityId': 16...
# 37  {'_id': 50bebf0414b6500c5cb795fc, 'CityId': 16...
# 38  {'_id': 50bebf0514b6500c5cb795ff, 'CityId': 16...
# 39  {'_id': 50bebf0614b6500c5cb79600, 'CityId': 16...
# 40  {'_id': 50bebf0f14b6500c5cb79619, 'CityId': 17...
# 41  {'_id': 50bebf1314b6500c5cb7961e, 'CityId': 17...
# 42  {'_id': 50bebf1414b6500c5cb79623, 'CityId': 17...
# 43  {'_id': 50bebf1614b6500c5cb79627, 'CityId': 17...
# 44  {'_id': 50bebf1614b6500c5cb79628, 'CityId': 17...
# 45  {'_id': 50bebf1914b6500c5cb79630, 'CityId': 17...
# 46  {'_id': 50bebf1d14b6500c5cb79638, 'CityId': 17...
# 47  {'_id': 50bebf3214b6500c5cb7966c, 'CityId': 17...
# 48  {'_id': 50bebf5114b6500c5cb796a2, 'CityId': 18...
# 49  {'_id': 50bebf6c14b6500c5cb796e6, 'CityId': 41...
# 50  {'_id': 50bebf7e14b6500c5cb7970f, 'CityId': 41...
# 51  {'_id': 50bebf8614b6500c5cb79726, 'CityId': 41...
# 52  {'_id': 50bebf8f14b6500c5cb7973b, 'CityId': 42...
# 53  {'_id': 50bebfb814b6500c5cb7979d, 'CityId': 42...

# %% [markdown]
# ## Exercise 4: MapReduce: Projection with Duplicates

# %% [markdown]
# Write a MapReduce program, which returns **solely the city names** of all Austrian cities. If duplicates are included, they should be **kept** in the result. How many Austrian city names are included in the dataset?

# %%
map = Code('function () { emit(this._id, this.City); }')
reduce = Code('function (key, values) { return values; }')
pd.DataFrame(cities.map_reduce(map, reduce, out='city_names_duplicates', query={'CountryID': 15}).find({}, {'_id': 0}))
# Out:
#                      value
# 0                  Abtenau
# 1                     Graz
# 2                Kitzbuhel
# 3               Lilienfeld
# 4                     Linz
# 5                 Salzburg
# 6                   Solden
# 7              Stegersbach
# 8                    Steyr
# 9                Innsbruck
# 10                  Vienna
# 11                Hohenems
# 12                 Bregenz
# 13                   Baden
# 14                       D
# 15                    Zirl
# 16                       W
# 17              Korneuburg
# 18              Wieselburg
# 19               Pinkafeld
# 20                Jochberg
# 21         Wiener Neustadt
# 22                 Zwettl
# 23                  Leoben
# 24             Feldkirchen
# 25                Dornbirn
# 26                Bad Hall
# 27                    Neud
# 28                Kindberg
# 29              Klagenfurt
# 30                       M
# 31             Neulengbach
# 32                       G
# 33                    Retz
# 34               Hagenberg
# 35              Eisenstadt
# 36                 Villach
# 37              Bodensdorf
# 38                Rosental
# 39                  Reutte
# 40                    Wels
# 41                       M
# 42                 Tamsweg
# 43                   Bad V
# 44                    Wien
# 45                       G
# 46              Grafenbach
# 47                 Sankt P
# 48             Zell am See
# 49  Sankt Johann im Pongau
# 50            Ebreichsdorf
# 51                       G
# 52                  Kremsm
# 53         Klosterneuburg

# %% [markdown]
# ## Exercise 5: MapReduce: Projection without Duplicates

# %% [markdown]
# Write a MapReduce program, which returns **solely the city names** of all Austrian cities. If duplicates are included, they should be **removed** from the result. Did duplicates arise? How many?

# %%
map = Code('function () { emit(this.City, this.City); }')
# just use first entry of values-list
reduce = Code('function (key, values) { return values[0]; }')
pd.DataFrame(cities.map_reduce(map, reduce, out='city_names_no_duplicates', query={'CountryID': 15}).find({}, {'_id': 0}))
# Out:
#                      value
# 0                  Abtenau
# 1                 Bad Hall
# 2                    Bad V
# 3                    Baden
# 4               Bodensdorf
# 5                  Bregenz
# 6                        D
# 7                 Dornbirn
# 8             Ebreichsdorf
# 9               Eisenstadt
# 10             Feldkirchen
# 11                       G
# 12              Grafenbach
# 13                    Graz
# 14               Hagenberg
# 15                Hohenems
# 16               Innsbruck
# 17                Jochberg
# 18                Kindberg
# 19               Kitzbuhel
# 20              Klagenfurt
# 21         Klosterneuburg
# 22              Korneuburg
# 23                  Kremsm
# 24                  Leoben
# 25              Lilienfeld
# 26                    Linz
# 27                       M
# 28                    Neud
# 29             Neulengbach
# 30               Pinkafeld
# 31                    Retz
# 32                  Reutte
# 33                Rosental
# 34                Salzburg
# 35  Sankt Johann im Pongau
# 36                 Sankt P
# 37                  Solden
# 38             Stegersbach
# 39                   Steyr
# 40                 Tamsweg
# 41                  Vienna
# 42                 Villach
# 43                       W
# 44                    Wels
# 45                    Wien
# 46         Wiener Neustadt
# 47              Wieselburg
# 48             Zell am See
# 49                    Zirl
# 50                 Zwettl

# %% [markdown]
# ## Exercise 6: MapReduce: Aggregation

# %% [markdown]
# Write a MapReduce program, which returns the total population of countries having EURO as currency. How many people are returned?

# %%
map = Code('function () { emit(this.CurrencyCode, this.Population); }')
# just use first entry of values-list
reduce = Code('function (key, values) { return values[0]; }')
pd.DataFrame(countries.map_reduce(map, reduce, out='currency_code_euro', query={'CurrencyCode': 'EUR'}).find({}, {'_id': 0}))
# Out:
#         value
# 0  10258762.0

# %%
map = Code('function () { emit(this.Currency, this.Population); }')
# just use first entry of values-list
reduce = Code('function (key, values) { return values[0]; }')
pd.DataFrame(countries.map_reduce(map, reduce, out='currency_euro', query={'Currency': 'Euro'}).find({}, {'_id': 0}))
# Out:
#         value
# 0  10258762.0

# %% [markdown]
# ## Exercise 7: MapReduce: Join

# %% [markdown]
# Write two MapReduce programs, which together produce a collection that represents a join between attributes of the `countries` and the `regions` collections. In terms of SQL, approximately the following query should be realized:
#
# ```SQL
# SELECT countries.Country, regions.Region
# FROM countries, regions
# WHERE regions.CountryID = countries.CountryId
# AND regions.CountryID = 15;
# ```
#
# The term “approximately” has been used, since the above query would return **one tuple for each region**. In contrast, the MapReduce program should return **a single document** with an array containing all regions.
#
# **Desired result:**
# ```
# {
#  "_id" : 15.0,
#  "value" : {
#  "Country" : "Austria",
#  "Region" : ["Austria", "Burgenland", "Karnten",
#  "Niederosterreich", "Oberosterreich", "Salzburg", "Steiermark",
#  "Tirol", "Vorarlberg", "Wien"]
#  }
# }
# ```
#
# **Hints for solution:**
#
# For achieving combined results, consider “reduce” semantics of MapReduce! Keep in mind that reduce may be applied to **structurally equal** documents, only! Pay attention to the three properties that must be guaranteed by the reduce function:
#
# - `reduce(key, [ C, reduce(key, [ A, B ]) ] ) == reduce (key, [ C, A, B ] )`
# - `reduce( key, [ reduce(key, [ A, B ]) ] ) == reduce ( key, [ A, B ] )`
# - `reduce ( key, [ A, B ] ) == reduce ( key, [ B, A ] )`
#
# Consequently, test the program with several invocations and in different execution order (e.g., first apply MapReduce to `countries`, then to `regions` and the other way round)!

# %%
map_regions = Code('function () { emit(this.CountryID, {_id: this.CountryID, Country: "", Region: [this.Region]}); }')
map_country = Code('function () { emit(this.CountryId, {_id: this.CountryId, Country: this.Country, Region: []}); }')

reduce = Code("""function (key, values) {
    const ret = {Country: "", Region: []};
    values.forEach(value => {
        if (ret.Country === "") {
            ret.Country = value.Country;
        }
        value.Region.forEach(region => {
            if (!ret.Region.includes(region)) {
                ret.Region.push(region);
            }
        });
    });
    return ret;
}""")

# %% [markdown]
# Testing invariance by order of execution

# %%
result = countries.map_reduce(map_country, reduce, out={'reduce': 'joined_country_first'})
result = regions.map_reduce(map_regions, reduce, out={'reduce': 'joined_country_first'})

for doc in result.find({'_id': 15}):
    pprint(doc)
# Out:
# {'_id': 15.0,
#  'value': {'Country': 'Austria',
#            'Region': ['Austria',
#                       'Burgenland',
#                       'Karnten',
#                       'Niederosterreich',
#                       'Oberosterreich',
#                       'Salzburg',
#                       'Steiermark',
#                       'Tirol',
#                       'Vorarlberg',
#                       'Wien']}}

# %%
result = regions.map_reduce(map_regions, reduce, out={'reduce': 'joined_regions_first'})
result = countries.map_reduce(map_country, reduce, out={'reduce': 'joined_regions_first'})

for doc in result.find({'_id': 15}):
    pprint(doc)
# Out:
# {'_id': 15.0,
#  'value': {'Country': 'Austria',
#            'Region': ['Austria',
#                       'Burgenland',
#                       'Karnten',
#                       'Niederosterreich',
#                       'Oberosterreich',
#                       'Salzburg',
#                       'Steiermark',
#                       'Tirol',
#                       'Vorarlberg',
#                       'Wien']}}
